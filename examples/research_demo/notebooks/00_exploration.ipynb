# %% [markdown]
# # Research Template Notebook
#
# Use this notebook for quick exploration, then move reusable logic into `src/research_demo_pkg/`.

# %%
from pathlib import Path
import sys

for candidate in [
    Path.cwd() / "src",
    Path.cwd().parent / "src",
    Path.cwd() / "examples" / "research_demo" / "src",
]:
    if candidate.exists():
        sys.path.insert(0, str(candidate.resolve()))
        break

from research_demo_pkg.research_helpers import summarize_notes

summarize_notes(["idea", "test", "result"])

# %% [markdown]
# ## Practice Lab
#
# Edit the note list to match a new experiment and generate a fresh summary.

# %%
practice_notes = ["baseline", "tweak", "evaluation"]
summarize_notes(practice_notes)

# %% [markdown]
# ## Active Learning Practice
#
# 1. Write three notes: hypothesis, method, result.
# 2. Generate summary text and review structure.
# 3. Add one follow-up experiment item.
# 4. Explain which parts should move to `src/` when reused.

# %%
study_notes = ["hypothesis", "method", "result", "next_experiment"]
summary_text = summarize_notes(study_notes)
{"count": len(study_notes), "preview": summary_text.splitlines()[:3]}
