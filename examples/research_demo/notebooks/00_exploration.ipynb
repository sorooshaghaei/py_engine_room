# %% [markdown]
# # Research Template Notebook\n\nUse this notebook for quick exploration, then move reusable logic into `src/research_demo_pkg/`.

# %%
from research_demo_pkg.research_helpers import summarize_notes\n\nsummarize_notes(["idea", "test", "result"])
